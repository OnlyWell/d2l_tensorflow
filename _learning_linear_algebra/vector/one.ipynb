# %%
#向量
import numpy as np
#1.长度

#向量
v = np.array([2,1])

# 向量长度计算
print(v[0]**2 + v[1]**2) ** (1/2)
# Out:
# 5
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[1], line 9
#       6 v = np.array([2,1])
#       8 # 向量长度计算
# ----> 9 print(v[0]**2 + v[1]**2) ** (1/2)
#
# TypeError: unsupported operand type(s) for ** or pow(): 'NoneType' and 'float'

# %%
# 使用np.linalg.norm()计算向量长度
magnitude = np.linalg.norm(v)
print(magnitude)
# Out:
# 2.23606797749979

# %%
# 2.方向
import math

v1 = np.array([2,1])

vTan = v[1] / v[0]
print('tan(0)=1/2')

theta = math.atan(vTan)
print('弧度(radian) = ',round(theta,4))
print('角度(radian) = ',round(theta * 180 /math.pi,2))

#也可以使用math.degrees()函数转化角度
print('角度(degree) = ', round(math.degrees(theta),2))
# Out:
# tan(0)=1/2
# 弧度(radian) =  0.4636
# 角度(radian) =  26.57
# 角度(degree) =  26.57
