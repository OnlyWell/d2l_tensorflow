# %%
'''
    重建卷积层处理后的影像:观察线条特征。透过多次的卷积层/池化层处理,观察图像的变化
    1.加载VGG16模型
    2.定义可视化滤波函数
    3.重建卷积层的输出图像
'''
import tensorflow as tf
from tensorflow.keras.applications.vgg16 import VGG16

import matplotlib.pyplot as plt
import numpy as np

model = VGG16()
model.summary()

def Visualize(layer_no=1,n_filters=6):
    #获取权重
    filters,biases = model.layers[layer_no].get_weights()
    #正态化
    f_min,f_max = filters.min(),filters.max()
    filters = (filters - f_min) / (f_max - f_min)

    #绘制特征图
    ix = 1
    for i in range(n_filters):
        f = filters[:,:,:,i] #取得每一张特征图
        for j in range(3): #每列3张图
            ax = plt.subplot(n_filters,3,ix) #指定子窗口
            ax.set_xticks([]) #无x轴刻度
            ax.set_Yticks([]) #无y轴刻度
            plt.imshow(f[:,:,j],cmap='gray') #以灰阶绘图
            ix += 1
    plt.show()
# Out:
# ...
# ---------------------------------------------------------------------------
# ConnectionResetError                      Traceback (most recent call last)
# File E:\develop\anaconda3\envs\d2l_tensorflow\Lib\urllib\request.py:1344, in AbstractHTTPHandler.do_open(self, http_class, req, **http_conn_args)
#    1343 try:
# -> 1344     h.request(req.get_method(), req.selector, req.data, headers,
#    1345               encode_chunked=req.has_header('Transfer-encoding'))
#    1346 except OSError as err: # timeout error
#
# File E:\develop\anaconda3\envs\d2l_tensorflow\Lib\http\client.py:1338, in HTTPConnection.request(self, method, url, body, headers, encode_chunked)
#    1337 """Send a complete request to the server."""
# -> 1338 self._send_request(method, url, body, headers, encode_chunked)
#
# File E:\develop\anaconda3\envs\d2l_tensorflow\Lib\http\client.py:1384, in HTTPConnection._send_request(self, method, url, body, headers, encode_chunked)
#    1383     body = _encode(body, 'body')
# ...
